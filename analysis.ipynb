# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\axel_\Documents\conda\random-games\playerStats\csv\arsenal-vs-atletico-madrid.csv')
df.head()
# Out:
#                  name      id  optaId  teamId            teamName  \
# 0           Jan Oblak  177126   81352    9906  Atlético de Madrid
# 1   Antoine Griezmann  184138   76650    9906  Atlético de Madrid
# 2                Koke  184533   77390    9906  Atlético de Madrid
# 3  Christian Nørgaard  266520  128295    9825             Arsenal
# 4   Kepa Arrizabalaga  317564  109745    9825             Arsenal
#
#    isGoalkeeper                                              stats  \
# 0          True  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 1         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 2         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 3         False                                                 []
# 4          True                                                 []
#
#    shirtNumber  positionId  usualPosition  ...  recoveries dribbled_past  \
# 0           13        11.0              0  ...         NaN           NaN
# 1            7       104.0              3  ...         0.0           1.0
# 2            6        74.0              2  ...         9.0           0.0
# 3           16         NaN              2  ...         NaN           NaN
# 4           13         NaN              0  ...         NaN           NaN
#
#   duel_won  duel_lost ground_duels_won_value  ground_duels_won_total  \
# 0      NaN        NaN                    NaN                     NaN
# 1      4.0        2.0                    2.0                     4.0
# 2      3.0        1.0                    2.0                     2.0
# 3      NaN        NaN                    NaN                     NaN
# 4      NaN        NaN                    NaN                     NaN
#
#   aerials_won_value  aerials_won_total  fouls_received  fouls_committed
# 0               NaN                NaN             NaN              NaN
# 1               2.0                2.0             1.0              0.0
# 2               1.0                2.0             1.0              0.0
# 3               NaN                NaN             NaN              NaN
# 4               NaN                NaN             NaN              NaN
#
# [5 rows x 55 columns]

# %%
# list header rows
header_list = df.columns.tolist()
print(header_list)
# Out:
# ['name', 'id', 'optaId', 'teamId', 'teamName', 'isGoalkeeper', 'stats', 'shirtNumber', 'positionId', 'usualPosition', 'matchId', 'matchRound', 'homeTeamName', 'homeTeamid', 'awayTeamName', 'awayTeamid', 'matchDate', 'home_goals', 'away_goals', 'FotMob_rating', 'Minutes_played', 'Goals', 'Assists', 'Total_shots', 'Accurate_passes_value', 'Accurate_passes_total', 'Chances_created', 'Expected_assists_xA', 'xG_plus_xA', 'Fantasy_points', 'Defensive_actions', 'touches', 'touches_opp_box', 'passes_into_final_third', 'accurate_crosses_value', 'accurate_crosses_total', 'long_balls_accurate_value', 'long_balls_accurate_total', 'dispossessed', 'tackles_succeeded_value', 'tackles_succeeded_total', 'shot_blocks', 'clearances', 'headed_clearance', 'interceptions', 'recoveries', 'dribbled_past', 'duel_won', 'duel_lost', 'ground_duels_won_value', 'ground_duels_won_total', 'aerials_won_value', 'aerials_won_total', 'fouls_received', 'fouls_committed']

# %%
# list header rows using list() function
header_list = list(df.columns)

# Using .values attribute
header_list = df.columns.values.tolist()
header_list
# Out:
# ['name',
#  'id',
#  'optaId',
#  'teamId',
#  'teamName',
#  'isGoalkeeper',
#  'stats',
#  'shirtNumber',
#  'positionId',
#  'usualPosition',
#  'matchId',
#  'matchRound',
#  'homeTeamName',
#  'homeTeamid',
#  'awayTeamName',
#  'awayTeamid',
#  'matchDate',
#  'home_goals',
#  'away_goals',
#  'FotMob_rating',
#  'Minutes_played',
#  'Goals',
#  'Assists',
#  'Total_shots',
#  'Accurate_passes_value',
#  'Accurate_passes_total',
#  'Chances_created',
#  'Expected_assists_xA',
#  'xG_plus_xA',
#  'Fantasy_points',
#  'Defensive_actions',
#  'touches',
#  'touches_opp_box',
#  'passes_into_final_third',
#  'accurate_crosses_value',
#  'accurate_crosses_total',
#  'long_balls_accurate_value',
#  'long_balls_accurate_total',
#  'dispossessed',
#  'tackles_succeeded_value',
#  'tackles_succeeded_total',
#  'shot_blocks',
#  'clearances',
#  'headed_clearance',
#  'interceptions',
#  'recoveries',
#  'dribbled_past',
#  'duel_won',
#  'duel_lost',
#  'ground_duels_won_value',
#  'ground_duels_won_total',
#  'aerials_won_value',
#  'aerials_won_total',
#  'fouls_received',
#  'fouls_committed']

# %%
# list header rows
df.columns
# Out:
# Index(['name', 'id', 'optaId', 'teamId', 'teamName', 'isGoalkeeper', 'stats',
#        'shirtNumber', 'positionId', 'usualPosition', 'matchId', 'matchRound',
#        'homeTeamName', 'homeTeamid', 'awayTeamName', 'awayTeamid', 'matchDate',
#        'home_goals', 'away_goals', 'FotMob_rating', 'Minutes_played', 'Goals',
#        'Assists', 'Total_shots', 'Accurate_passes_value',
#        'Accurate_passes_total', 'Chances_created', 'Expected_assists_xA',
#        'xG_plus_xA', 'Fantasy_points', 'Defensive_actions', 'touches',
#        'touches_opp_box', 'passes_into_final_third', 'accurate_crosses_value',
#        'accurate_crosses_total', 'long_balls_accurate_value',
#        'long_balls_accurate_total', 'dispossessed', 'tackles_succeeded_value',
#        'tackles_succeeded_total', 'shot_blocks', 'clearances',
#        'headed_clearance', 'interceptions', 'recoveries', 'dribbled_past',
#        'duel_won', 'duel_lost', 'ground_duels_won_value',
#        'ground_duels_won_total', 'aerials_won_value', 'aerials_won_total',
#        'fouls_received', 'fouls_committed'],
#       dtype='str')

# %%
# read each column
df[['name', 'teamName']].head()
# Out:
#                  name            teamName
# 0           Jan Oblak  Atlético de Madrid
# 1   Antoine Griezmann  Atlético de Madrid
# 2                Koke  Atlético de Madrid
# 3  Christian Nørgaard             Arsenal
# 4   Kepa Arrizabalaga             Arsenal

# %%
# Count how many times each team name appears
df['teamName'].value_counts()
# Out:
# teamName
# Atlético de Madrid    23
# Arsenal               23
# Name: count, dtype: int64

# %%
# Or using groupby
df.groupby('teamName').size()
# Out:
# teamName
# Arsenal               23
# Atlético de Madrid    23
# dtype: int64

# %%
# Group by name and show various statistics
grouped_stats = df.groupby('teamName').agg({
    'teamName': 'count',  # count occurrences
    # Add other columns you want to aggregate
}).rename(columns={'teamName': 'count'})

print(grouped_stats)
# Out:
#                     count
# teamName
# Arsenal                23
# Atlético de Madrid     23

# %%
# See all unique names
df['teamName'].unique()
# Out:
# <StringArray>
# ['Atlético de Madrid', 'Arsenal']
# Length: 2, dtype: str

# %%
# get row based on a specific condition
df.loc[df['teamName'] == 'Atlético de Madrid'].head(2)
# Out:
#                 name      id  optaId  teamId            teamName  \
# 0          Jan Oblak  177126   81352    9906  Atlético de Madrid
# 1  Antoine Griezmann  184138   76650    9906  Atlético de Madrid
#
#    isGoalkeeper                                              stats  \
# 0          True  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 1         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#    shirtNumber  positionId  usualPosition  ...  recoveries dribbled_past  \
# 0           13        11.0              0  ...         NaN           NaN
# 1            7       104.0              3  ...         0.0           1.0
#
#   duel_won  duel_lost ground_duels_won_value  ground_duels_won_total  \
# 0      NaN        NaN                    NaN                     NaN
# 1      4.0        2.0                    2.0                     4.0
#
#   aerials_won_value  aerials_won_total  fouls_received  fouls_committed
# 0               NaN                NaN             NaN              NaN
# 1               2.0                2.0             1.0              0.0
#
# [2 rows x 55 columns]

# %%
# describe data
df.describe()
# Out:
#                  id         optaId       teamId  shirtNumber  positionId  \
# count  4.600000e+01      46.000000    46.000000    46.000000   22.000000
# mean   8.883986e+05  331216.500000  9865.500000    18.239130   61.454545
# std    4.165558e+05  176660.157626    40.947527    16.756007   32.021908
# min    1.771260e+05   76650.000000  9825.000000     1.000000   11.000000
# 25%    5.827645e+05  193990.250000  9825.000000     7.000000   34.500000
# 50%    9.488215e+05  241797.000000  9865.500000    14.000000   72.500000
# 75%    1.213030e+06  488494.500000  9906.000000    21.750000   77.750000
# max    1.787525e+06  616077.000000  9906.000000    89.000000  107.000000
#
#        usualPosition    matchId  homeTeamid  awayTeamid  home_goals  ...  \
# count      46.000000       46.0        46.0        46.0        46.0  ...
# mean        1.565217  5205813.0      9906.0      9825.0         1.0  ...
# std         0.958058        0.0         0.0         0.0         0.0  ...
# min         0.000000  5205813.0      9906.0      9825.0         1.0  ...
# 25%         1.000000  5205813.0      9906.0      9825.0         1.0  ...
# 50%         1.500000  5205813.0      9906.0      9825.0         1.0  ...
# 75%         2.000000  5205813.0      9906.0      9825.0         1.0  ...
# max         3.000000  5205813.0      9906.0      9825.0         1.0  ...
#
#        recoveries  dribbled_past   duel_won  duel_lost  \
# count   28.000000      28.000000  24.000000  26.000000
# mean     2.571429       0.571429   3.166667   2.923077
# std      2.218250       0.790151   1.578846   1.572847
# min      0.000000       0.000000   1.000000   1.000000
# 25%      1.000000       0.000000   2.000000   1.250000
# 50%      2.500000       0.000000   3.000000   3.000000
# 75%      4.000000       1.000000   4.000000   4.000000
# max      9.000000       3.000000   7.000000   6.000000
#
#        ground_duels_won_value  ground_duels_won_total  aerials_won_value  \
# count               26.000000               26.000000          28.000000
# mean                 2.269231                4.538462           0.607143
# std                  1.282426                2.231247           0.956045
# min                  0.000000                1.000000           0.000000
# 25%                  1.250000                3.000000           0.000000
# 50%                  2.000000                4.000000           0.000000
# 75%                  3.000000                6.000000           1.000000
# max                  5.000000                8.000000           4.000000
#
#        aerials_won_total  fouls_received  fouls_committed
# count          28.000000       12.000000        28.000000
# mean            1.214286        1.166667         0.642857
# std             1.066567        0.389249         0.826160
# min             0.000000        1.000000         0.000000
# 25%             0.000000        1.000000         0.000000
# 50%             1.000000        1.000000         0.000000
# 75%             2.000000        1.000000         1.000000
# max             4.000000        2.000000         3.000000
#
# [8 rows x 47 columns]

# %%
# sort values
df.sort_values(['name', 'shirtNumber'], ascending=False).head()
# Out:
#                name       id  optaId  teamId            teamName  \
# 22       Álex Baena   942372  248501    9906  Atlético de Madrid
# 24   William Saliba   955406  462424    9825             Arsenal
# 15  Viktor Gyökeres   664500  224117    9825             Arsenal
# 35    Tommy Setford  1243239  551221    9825             Arsenal
# 23    Thiago Almada   955271  461360    9906  Atlético de Madrid
#
#     isGoalkeeper                                              stats  \
# 22         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 24         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 15         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 35          True                                                 []
# 23         False                                                 []
#
#     shirtNumber  positionId  usualPosition  ...  recoveries dribbled_past  \
# 22           10         NaN              2  ...         3.0           0.0
# 24            2        34.0              1  ...         6.0           0.0
# 15           14       105.0              3  ...         1.0           0.0
# 35           35         NaN              0  ...         NaN           NaN
# 23           11         NaN              2  ...         NaN           NaN
#
#    duel_won  duel_lost ground_duels_won_value  ground_duels_won_total  \
# 22      2.0        1.0                    2.0                     2.0
# 24      2.0        1.0                    1.0                     1.0
# 15      5.0        2.0                    1.0                     3.0
# 35      NaN        NaN                    NaN                     NaN
# 23      NaN        NaN                    NaN                     NaN
#
#    aerials_won_value  aerials_won_total  fouls_received  fouls_committed
# 22               0.0                1.0             NaN              0.0
# 24               1.0                2.0             NaN              0.0
# 15               4.0                4.0             1.0              3.0
# 35               NaN                NaN             NaN              NaN
# 23               NaN                NaN             NaN              NaN
#
# [5 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 56 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   name                       46 non-null     str
#  1   id                         46 non-null     int64
#  2   optaId                     46 non-null     int64
#  3   teamId                     46 non-null     int64
#  4   teamName                   46 non-null     str
#  5   isGoalkeeper               46 non-null     bool
#  6   stats                      46 non-null     str
#  7   shirtNumber                46 non-null     int64
#  8   positionId                 22 non-null     float64
#  9   usualPosition              46 non-null     int64
#  10  matchId                    46 non-null     int64
#  11  matchRound                 46 non-null     str
#  12  homeTeamName               46 non-null     str
#  13  homeTeamid                 46 non-null     int64
#  14  awayTeamName               46 non-null     str
#  15  awayTeamid                 46 non-null     int64
#  16  matchDate                  46 non-null     str
#  17  home_goals                 46 non-null     int64
#  18  away_goals                 46 non-null     int64
#  19  FotMob_rating              28 non-null     float64
#  20  Minutes_played             30 non-null     float64
#  21  Goals                      28 non-null     float64
#  22  Assists                    28 non-null     float64
#  23  Total_shots                0 non-null      float64
#  24  Accurate_passes_value      30 non-null     float64
#  25  Accurate_passes_total      30 non-null     float64
#  26  Chances_created            28 non-null     float64
#  27  Expected_assists_xA        25 non-null     float64
#  28  xG_plus_xA                 26 non-null     float64
#  29  Fantasy_points             0 non-null      float64
#  30  Defensive_actions          30 non-null     float64
#  31  touches                    28 non-null     float64
#  32  touches_opp_box            28 non-null     float64
#  33  passes_into_final_third    22 non-null     float64
#  34  accurate_crosses_value     10 non-null     float64
#  35  accurate_crosses_total     10 non-null     float64
#  36  long_balls_accurate_value  17 non-null     float64
#  37  long_balls_accurate_total  17 non-null     float64
#  38  dispossessed               28 non-null     float64
#  39  tackles_succeeded_value    0 non-null      float64
#  40  tackles_succeeded_total    0 non-null      float64
#  41  shot_blocks                28 non-null     float64
#  42  clearances                 28 non-null     float64
#  43  headed_clearance           6 non-null      float64
#  44  interceptions              28 non-null     float64
#  45  recoveries                 28 non-null     float64
#  46  dribbled_past              28 non-null     float64
#  47  duel_won                   24 non-null     float64
#  48  duel_lost                  26 non-null     float64
#  49  ground_duels_won_value     26 non-null     float64
#  50  ground_duels_won_total     26 non-null     float64
#  51  aerials_won_value          28 non-null     float64
#  52  aerials_won_total          28 non-null     float64
#  53  fouls_received             12 non-null     float64
#  54  fouls_committed            28 non-null     float64
#  55  stats_parsed               46 non-null     object
# dtypes: bool(1), float64(37), int64(10), object(1), str(7)
# memory usage: 19.9+ KB

# %%
df['stats'][1]
# Out:
# "[{'title': 'Top stats', 'key': 'top_stats', 'stats': {'FotMob rating': {'key': 'rating_title', 'stat': {'value': 7.41, 'type': 'double'}}, 'Minutes played': {'key': 'minutes_played', 'stat': {'value': 90, 'type': 'integer'}}, 'Goals': {'key': 'goals', 'stat': {'value': 0, 'type': 'integer'}}, 'Assists': {'key': 'assists', 'stat': {'value': 0, 'type': 'integer'}}, 'Expected goals (xG)': {'key': 'expected_goals', 'stat': {'value': 0.46, 'type': 'double'}}, 'Expected goals on target (xGOT)': {'key': 'expected_goals_on_target_variant', 'stat': {'type': 'double'}}, 'Expected assists (xA)': {'key': 'expected_assists', 'stat': {'value': 0.14, 'type': 'double'}}, 'xG + xA': {'key': 'xg_and_xa', 'stat': {'value': 0.6000000000000001, 'type': 'double'}}, 'Accurate passes': {'key': 'accurate_passes', 'stat': {'value': 39, 'total': 48, 'type': 'fractionWithPercentage'}}, 'Chances created': {'key': 'chances_created', 'stat': {'value': 2, 'type': 'integer'}}, 'Shots on target': {'key': 'ShotsOnTarget', 'stat': {'value': 0, 'type': 'integer'}}, 'Shots off target': {'key': 'ShotsOffTarget', 'stat': {'value': 1, 'type': 'integer'}}, 'Blocked shots': {'key': 'blocked_shots', 'stat': {'value': 3, 'type': 'integer'}}, 'Shot accuracy': {'key': 'shot_accuracy', 'stat': {'value': 0, 'total': 1, 'type': 'fractionWithPercentage'}}, 'Shotmap': {'key': None, 'stat': {'value': 1, 'type': 'boolean'}}, 'Defensive actions': {'key': 'defensive_actions', 'stat': {'value': 2, 'type': 'integer'}}}}, {'title': 'Attack', 'key': 'attack', 'stats': {'Hit woodwork': {'key': 'shots_woodwork', 'stat': {'value': 1, 'type': 'integer'}}, 'Touches': {'key': 'touches', 'stat': {'value': 62, 'type': 'integer'}}, 'Touches in opposition box': {'key': 'touches_opp_box', 'stat': {'value': 5, 'type': 'integer'}}, 'Passes into final third': {'key': 'passes_into_final_third', 'stat': {'value': 3, 'type': 'integer'}}, 'Accurate crosses': {'key': 'accurate_crosses', 'stat': {'value': 2, 'total': 5, 'type': 'fractionWithPercentage'}}, 'Accurate long balls': {'key': 'long_balls_accurate', 'stat': {'value': 1, 'total': 3, 'type': 'fractionWithPercentage'}}, 'Corners': {'key': 'corners', 'stat': {'value': 3, 'type': 'integer'}}, 'Dispossessed': {'key': 'dispossessed', 'stat': {'value': 1, 'type': 'integer'}}, 'xG Non-penalty': {'key': 'expected_goals_non_penalty', 'stat': {'value': 0.46, 'type': 'double'}}}}, {'title': 'Defense', 'key': 'defense', 'stats': {'Defensive actions': {'key': 'defensive_actions', 'stat': {'value': 2, 'type': 'integer'}}, 'Tackles': {'key': 'matchstats.headers.tackles', 'stat': {'value': 1, 'type': 'integer'}}, 'Blocks': {'key': 'shot_blocks', 'stat': {'value': 0, 'type': 'integer'}}, 'Clearances': {'key': 'clearances', 'stat': {'value': 1, 'type': 'integer'}}, 'Headed clearance': {'key': 'headed_clearance', 'stat': {'value': 1, 'type': 'integer'}}, 'Interceptions': {'key': 'interceptions', 'stat': {'value': 0, 'type': 'integer'}}, 'Recoveries': {'key': 'recoveries', 'stat': {'value': 0, 'type': 'integer'}}, 'Dribbled past': {'key': 'dribbled_past', 'stat': {'value': 1, 'type': 'integer'}}}}, {'title': 'Duels', 'key': 'duels', 'stats': {'Ground duels won': {'key': 'ground_duels_won', 'stat': {'value': 2, 'total': 4, 'type': 'fractionWithPercentage'}}, 'Aerial duels won': {'key': 'aerials_won', 'stat': {'value': 2, 'total': 2, 'type': 'fractionWithPercentage'}}, 'Was fouled': {'key': 'was_fouled', 'stat': {'value': 1, 'type': 'integer'}}, 'Fouls committed': {'key': 'fouls', 'stat': {'value': 0, 'type': 'integer'}}, 'Duels won': {'key': 'duel_won', 'stat': {'value': 4, 'type': 'integer'}, 'hideInPopupCard': True}, 'Duels lost': {'key': 'duel_lost', 'stat': {'value': 2, 'type': 'integer'}, 'hideInPopupCard': True}}}]"

# %%
import json
import ast

# %%
# convert stats column to dict
df['stats_parsed'] = df['stats'].apply(ast.literal_eval)

# %%
df.head(1)
# Out:
#         name      id  optaId  teamId            teamName  isGoalkeeper  \
# 0  Jan Oblak  177126   81352    9906  Atlético de Madrid          True
#
#                                                stats  shirtNumber  positionId  \
# 0  [{'title': 'Top stats', 'key': 'top_stats', 's...           13        11.0
#
#    usualPosition  ...  dribbled_past duel_won duel_lost  \
# 0              0  ...            NaN      NaN       NaN
#
#    ground_duels_won_value ground_duels_won_total  aerials_won_value  \
# 0                     NaN                    NaN                NaN
#
#   aerials_won_total  fouls_received  fouls_committed  \
# 0               NaN             NaN              NaN
#
#                                         stats_parsed
# 0  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
# [1 rows x 56 columns]

# %%
# xG
df['stats_parsed'][1][0]['stats']['Expected goals (xG)']['stat']['value']
# Out:
# 0.46

# %%
# xG
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Expected goals (xG)']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['xG'] = df['stats_parsed'].apply(extract)

# %%
# xGOT
df['stats_parsed'][1][0]['stats']['Expected goals on target (xGOT)']['stat']['value']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df['stats_parsed'][23][0]['stats']['Expected goals on target (xGOT)']['stat']['value']
#
# IndexError: list index out of range

# %%
# xGOT
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Expected goals on target (xGOT)']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['xGOT'] = df['stats_parsed'].apply(extract)

# %%
# Shots on target
df['stats_parsed'][1][0]['stats']['Shots on target']['stat']['value']
# Out:
# 0

# %%
# Shots on target
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Shots on target']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['shots_on_target'] = df['stats_parsed'].apply(extract)

# %%
# Shots off target
df['stats_parsed'][1][0]['stats']['Shots off target']['stat']['value']
# Out:
# 1

# %%
# Shots off target
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Shots off target']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['shots_off_target'] = df['stats_parsed'].apply(extract)

# %%
# Blocked shots
df['stats_parsed'][1][0]['stats']['Blocked shots']['stat']['value']
# Out:
# 3

# %%
# Blocked shots
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Blocked shots']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['blocked_shots'] = df['stats_parsed'].apply(extract)

# %%
# Shot accuracy
df['stats_parsed'][1][0]['stats']['Shot accuracy']['stat']['value']
# Out:
# 0

# %%
# Shot accuracy
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Shot accuracy']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['shot_accuracy'] = df['stats_parsed'].apply(extract)

# %%
# Hit woodwork 
df['stats_parsed'][1][1]['stats']['Hit woodwork']['stat']['value']
# Out:
# 1

# %%
# Hit woodwork
def extract(stats_parsed):
    try:
        return stats_parsed[1]['stats']['Hit woodwork']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['hit_woodwork'] = df['stats_parsed'].apply(extract)

# %%
# Corners
df['stats_parsed'][1][1]['stats']['Corners']['stat']['value']
# Out:
# 3

# %%
# corners
def extract(stats_parsed):
    try:
        return stats_parsed[1]['stats']['Corners']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['corners'] = df['stats_parsed'].apply(extract)

# %%
# xG non penalty
df['stats_parsed'][1][1]['stats']['xG Non-penalty']['stat']['value']
# Out:
# 0.46

# %%
# xG non penalty
def extract(stats_parsed):
    try:
        return stats_parsed[1]['stats']['xG Non-penalty']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['xG_non_penalty'] = df['stats_parsed'].apply(extract)

# %%
# tackles
df['stats_parsed'][1][2]['stats']['Tackles']['stat']['value']
# Out:
# 1

# %%
# tackles
def extract(stats_parsed):
    try:
        return stats_parsed[2]['stats']['Tackles']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['tackles'] = df['stats_parsed'].apply(extract)

# %%
# shot_blocks
df['stats_parsed'][1][2]['stats']['Blocks']['stat']['value']
# Out:
# 0

# %%
# shot_blocks
def extract(stats_parsed):
    try:
        return stats_parsed[2]['stats']['Blocks']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['shot_blocks'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper saves
df['stats_parsed'][0][0]['stats']['Saves']['stat']['value']
# Out:
# 1

# %%
# goal keeper saves
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Saves']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_saves'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper goals conceded
df['stats_parsed'][0][0]['stats']['Goals conceded']['stat']['value']
# Out:
# 1

# %%
# goal keeper goals conceded
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Goals conceded']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_goals_conceded'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper xGOT faced
df['stats_parsed'][0][0]['stats']['xGOT faced']['stat']['value']
# Out:
# 0.7

# %%
# goal keeper xGOT faced
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['xGOT faced']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_xGOT_faced'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper goals prevented
df['stats_parsed'][0][0]['stats']['Goals prevented']['stat']['value']
# Out:
# -0.3

# %%
# goal keeper goals prevented
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Goals prevented']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_goals_prevented'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper diving save
df['stats_parsed'][0][0]['stats']['Diving save']['stat']['value']
# Out:
# 0

# %%
# goal keeper diving save
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Diving save']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_diving_save'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper saves inside box
df['stats_parsed'][0][0]['stats']['Saves inside box']['stat']['value']
# Out:
# 0

# %%
# goal keeper saves inside box
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Saves inside box']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_saves_inside_box'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper acted as sweeper
df['stats_parsed'][0][0]['stats']['Acted as sweeper']['stat']['value']
# Out:
# 2

# %%
# goal keeper acted as sweeper
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Acted as sweeper']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_acted_as_sweeper'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper punches
df['stats_parsed'][0][0]['stats']['Punches']['stat']['value']
# Out:
# 0

# %%
# goal keeper punches
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Punches']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_punches'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper throws
df['stats_parsed'][0][0]['stats']['Throws']['stat']['value']
# Out:
# 3

# %%
# goal keeper throws
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['Throws']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_throws'] = df['stats_parsed'].apply(extract)

# %%
# goal keeper high claim
df['stats_parsed'][0][0]['stats']['High claim']['stat']['value']
# Out:
# 0

# %%
# goal keeper high claim
def extract(stats_parsed):
    try:
        return stats_parsed[0]['stats']['High claim']['stat']['value']
    except (KeyError, IndexError, TypeError):
        return None  # or np.nan

df['gk_high_claim'] = df['stats_parsed'].apply(extract)

# %%
# Save to CSV
df.to_csv(r'C:\Users\axel_\Documents\conda\random-games\playerStats\csv\arsenal-vs-atletico-madrid-v1.csv', index=False)

# %%
c_df = pd.read_csv(r'C:\Users\axel_\Documents\conda\random-games\playerStats\csv\arsenal-vs-atletico-madrid-v1.csv')
c_df
# Out:
#                   name       id  optaId  teamId            teamName  \
# 0            Jan Oblak   177126   81352    9906  Atlético de Madrid
# 1    Antoine Griezmann   184138   76650    9906  Atlético de Madrid
# 2                 Koke   184533   77390    9906  Atlético de Madrid
# 3   Christian Nørgaard   266520  128295    9825             Arsenal
# 4    Kepa Arrizabalaga   317564  109745    9825             Arsenal
# 5     Leandro Trossard   318615  116216    9825             Arsenal
# 6           Juan Musso   389050  121537    9906  Atlético de Madrid
# 7    Alexander Sørloth   440330  143877    9906  Atlético de Madrid
# 8      Clément Lenglet   488412  171101    9906  Atlético de Madrid
# 9      Martin Ødegaard   534670  184029    9825             Arsenal
# 10          David Raya   562727  154561    9825             Arsenal
# 11       Gabriel Jesus   576165  205651    9825             Arsenal
# 12     Marcos Llorente   602563  192364    9906  Atlético de Madrid
# 13    Robin Le Normand   609516  224919    9906  Atlético de Madrid
# 14         Declan Rice   654096  204480    9825             Arsenal
# 15     Viktor Gyökeres   664500  224117    9825             Arsenal
# 16     Ademola Lookman   690516  219352    9906  Atlético de Madrid
# 17       Nahuel Molina   726345  221586    9906  Atlético de Madrid
# 18        Dávid Hancko   727897  235093    9906  Atlético de Madrid
# 19           Ben White   776151  198869    9825             Arsenal
# 20             Gabriel   795179  226597    9825             Arsenal
# 21        Eberechi Eze   818975  232413    9825             Arsenal
# 22          Álex Baena   942372  248501    9906  Atlético de Madrid
# 23       Thiago Almada   955271  461360    9906  Atlético de Madrid
# 24      William Saliba   955406  462424    9825             Arsenal
# 25         Bukayo Saka   961995  223340    9825             Arsenal
# 26      Julián Álvarez   974753  461358    9906  Atlético de Madrid
# 27  Gabriel Martinelli  1021586  444145    9825             Arsenal
# 28    Martín Zubimendi  1031325  481655    9825             Arsenal
# 29      Matteo Ruggeri  1051097  487992    9906  Atlético de Madrid
# 30        Noni Madueke  1084981  248857    9825             Arsenal
# 31  Riccardo Calafiori  1105912  466075    9825             Arsenal
# 32      Piero Hincapié  1137667  448104    9825             Arsenal
# 33      Johnny Cardoso  1173678  488662    9906  Atlético de Madrid
# 34    Giuliano Simeone  1226147  482652    9906  Atlético de Madrid
# 35       Tommy Setford  1243239  551221    9825             Arsenal
# 36         Obed Vargas  1254394  502868    9906  Atlético de Madrid
# 37  Cristhian Mosquera  1298907  500040    9825             Arsenal
# 38         Marc Pubill  1323897  562720    9906  Atlético de Madrid
# 39        Javier Boñar  1367926  551310    9906  Atlético de Madrid
# 40  Myles Lewis-Skelly  1406436  499169    9825             Arsenal
# 41     Rodrigo Mendoza  1419969  578538    9906  Atlético de Madrid
# 42          Julio Díaz  1447089  551311    9906  Atlético de Madrid
# 43      Salvi Esquivel  1553402  551321    9906  Atlético de Madrid
# 44          Max Dowman  1635773  616077    9825             Arsenal
# 45        Marli Salmon  1787525  616065    9825             Arsenal
#
#     isGoalkeeper                                              stats  \
# 0           True  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 1          False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 2          False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 3          False                                                 []
# 4           True                                                 []
# 5          False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 6           True                                                 []
# 7          False                                                 []
# 8          False                                                 []
# 9          False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 10          True  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 11         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 12         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 13         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 14         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 15         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 16         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 17         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 18         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 19         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 20         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 21         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 22         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 23         False                                                 []
# 24         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 25         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 26         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 27         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 28         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 29         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 30         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 31         False                                                 []
# 32         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 33         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 34         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 35          True                                                 []
# 36         False                                                 []
# 37         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 38         False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 39         False                                                 []
# 40         False                                                 []
# 41         False                                                 []
# 42         False                                                 []
# 43          True                                                 []
# 44         False                                                 []
# 45         False                                                 []
#
#     shirtNumber  positionId  usualPosition  ...  gk_saves gk_goals_conceded  \
# 0            13        11.0              0  ...       1.0               1.0
# 1             7       104.0              3  ...       NaN               NaN
# 2             6        74.0              2  ...       NaN               NaN
# 3            16         NaN              2  ...       NaN               NaN
# 4            13         NaN              0  ...       NaN               NaN
# 5            19         NaN              3  ...       NaN               NaN
# 6             1         NaN              0  ...       NaN               NaN
# 7             9         NaN              3  ...       NaN               NaN
# 8            15         NaN              1  ...       NaN               NaN
# 9             8        73.0              2  ...       NaN               NaN
# 10            1        11.0              0  ...       3.0               1.0
# 11            9         NaN              3  ...       NaN               NaN
# 12           14        32.0              1  ...       NaN               NaN
# 13           24         NaN              1  ...       NaN               NaN
# 14           41        77.0              2  ...       NaN               NaN
# 15           14       105.0              3  ...       NaN               NaN
# 16           22        78.0              2  ...       NaN               NaN
# 17           16         NaN              1  ...       NaN               NaN
# 18           17        36.0              1  ...       NaN               NaN
# 19            4        32.0              1  ...       NaN               NaN
# 20            6        36.0              1  ...       NaN               NaN
# 21           10         NaN              2  ...       NaN               NaN
# 22           10         NaN              2  ...       NaN               NaN
# 23           11         NaN              2  ...       NaN               NaN
# 24            2        34.0              1  ...       NaN               NaN
# 25            7         NaN              3  ...       NaN               NaN
# 26           19       106.0              3  ...       NaN               NaN
# 27           11       107.0              3  ...       NaN               NaN
# 28           36        75.0              2  ...       NaN               NaN
# 29            3        38.0              1  ...       NaN               NaN
# 30           20       103.0              3  ...       NaN               NaN
# 31           33         NaN              1  ...       NaN               NaN
# 32            5        38.0              1  ...       NaN               NaN
# 33            5        76.0              2  ...       NaN               NaN
# 34           20        72.0              2  ...       NaN               NaN
# 35           35         NaN              0  ...       NaN               NaN
# 36           21         NaN              2  ...       NaN               NaN
# 37            3         NaN              1  ...       NaN               NaN
# 38           18        34.0              1  ...       NaN               NaN
# 39           32         NaN              1  ...       NaN               NaN
# 40           49         NaN              1  ...       NaN               NaN
# 41            4         NaN              2  ...       NaN               NaN
# 42           34         NaN              1  ...       NaN               NaN
# 43           31         NaN              0  ...       NaN               NaN
# 44           56         NaN              2  ...       NaN               NaN
# 45           89         NaN              1  ...       NaN               NaN
#
#    gk_xGOT_faced  gk_goals_prevented gk_diving_save  gk_saves_inside_box  \
# 0           0.70               -0.30            0.0                  0.0
# 1            NaN                 NaN            NaN                  NaN
# 2            NaN                 NaN            NaN                  NaN
# 3            NaN                 NaN            NaN                  NaN
# 4            NaN                 NaN            NaN                  NaN
# 5            NaN                 NaN            NaN                  NaN
# 6            NaN                 NaN            NaN                  NaN
# 7            NaN                 NaN            NaN                  NaN
# 8            NaN                 NaN            NaN                  NaN
# 9            NaN                 NaN            NaN                  NaN
# 10          1.79                0.79            2.0                  2.0
# 11           NaN                 NaN            NaN                  NaN
# 12           NaN                 NaN            NaN                  NaN
# 13           NaN                 NaN            NaN                  NaN
# 14           NaN                 NaN            NaN                  NaN
# 15           NaN                 NaN            NaN                  NaN
# 16           NaN                 NaN            NaN                  NaN
# 17           NaN                 NaN            NaN                  NaN
# 18           NaN                 NaN            NaN                  NaN
# 19           NaN                 NaN            NaN                  NaN
# 20           NaN                 NaN            NaN                  NaN
# 21           NaN                 NaN            NaN                  NaN
# 22           NaN                 NaN            NaN                  NaN
# 23           NaN                 NaN            NaN                  NaN
# 24           NaN                 NaN            NaN                  NaN
# 25           NaN                 NaN            NaN                  NaN
# 26           NaN                 NaN            NaN                  NaN
# 27           NaN                 NaN            NaN                  NaN
# 28           NaN                 NaN            NaN                  NaN
# 29           NaN                 NaN            NaN                  NaN
# 30           NaN                 NaN            NaN                  NaN
# 31           NaN                 NaN            NaN                  NaN
# 32           NaN                 NaN            NaN                  NaN
# 33           NaN                 NaN            NaN                  NaN
# 34           NaN                 NaN            NaN                  NaN
# 35           NaN                 NaN            NaN                  NaN
# 36           NaN                 NaN            NaN                  NaN
# 37           NaN                 NaN            NaN                  NaN
# 38           NaN                 NaN            NaN                  NaN
# 39           NaN                 NaN            NaN                  NaN
# 40           NaN                 NaN            NaN                  NaN
# 41           NaN                 NaN            NaN                  NaN
# 42           NaN                 NaN            NaN                  NaN
# 43           NaN                 NaN            NaN                  NaN
# 44           NaN                 NaN            NaN                  NaN
# 45           NaN                 NaN            NaN                  NaN
#
#    gk_acted_as_sweeper  gk_punches  gk_throws  gk_high_claim
# 0                  2.0         0.0        3.0            0.0
# 1                  NaN         NaN        NaN            NaN
# 2                  NaN         NaN        NaN            NaN
# 3                  NaN         NaN        NaN            NaN
# 4                  NaN         NaN        NaN            NaN
# 5                  NaN         NaN        NaN            NaN
# 6                  NaN         NaN        NaN            NaN
# 7                  NaN         NaN        NaN            NaN
# 8                  NaN         NaN        NaN            NaN
# 9                  NaN         NaN        NaN            NaN
# 10                 1.0         1.0        6.0            1.0
# 11                 NaN         NaN        NaN            NaN
# 12                 NaN         NaN        NaN            NaN
# 13                 NaN         NaN        NaN            NaN
# 14                 NaN         NaN        NaN            NaN
# 15                 NaN         NaN        NaN            NaN
# 16                 NaN         NaN        NaN            NaN
# 17                 NaN         NaN        NaN            NaN
# 18                 NaN         NaN        NaN            NaN
# 19                 NaN         NaN        NaN            NaN
# 20                 NaN         NaN        NaN            NaN
# 21                 NaN         NaN        NaN            NaN
# 22                 NaN         NaN        NaN            NaN
# 23                 NaN         NaN        NaN            NaN
# 24                 NaN         NaN        NaN            NaN
# 25                 NaN         NaN        NaN            NaN
# 26                 NaN         NaN        NaN            NaN
# 27                 NaN         NaN        NaN            NaN
# 28                 NaN         NaN        NaN            NaN
# 29                 NaN         NaN        NaN            NaN
# 30                 NaN         NaN        NaN            NaN
# 31                 NaN         NaN        NaN            NaN
# 32                 NaN         NaN        NaN            NaN
# 33                 NaN         NaN        NaN            NaN
# 34                 NaN         NaN        NaN            NaN
# 35                 NaN         NaN        NaN            NaN
# 36                 NaN         NaN        NaN            NaN
# 37                 NaN         NaN        NaN            NaN
# 38                 NaN         NaN        NaN            NaN
# 39                 NaN         NaN        NaN            NaN
# 40                 NaN         NaN        NaN            NaN
# 41                 NaN         NaN        NaN            NaN
# 42                 NaN         NaN        NaN            NaN
# 43                 NaN         NaN        NaN            NaN
# 44                 NaN         NaN        NaN            NaN
# 45                 NaN         NaN        NaN            NaN
#
# [46 rows x 76 columns]
